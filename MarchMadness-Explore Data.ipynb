# %%
##LOAD PACKAGES

import glob
import pandas as pd
from pylab import *
import numpy as np

#SETTINGS

# %matplotlib inline
pd.set_option('display.max_columns',0)

# %% [markdown]
# ## THE DATA:
#     <ol>
#     <li>From Sports Reference:</li>

# %%
##READ IN DATA

sportsRef1 = pd.read_csv("./ScrapeData/Output/2010_11_12_to_2012_01_13_NCAABBData.csv")
sportsRef2 = pd.read_csv("./ScrapeData/Output/2012_01_14_to_2013_11_11_NCAABBData.csv")
sportsRefAll = sportsRef1.append(sportsRef2)
sportsRefAll['DateNum'] = pd.to_datetime(sportsRefAll['Date'])
sportsRefAll = sportsRefAll.set_index('DateNum')
sportsRefAll.describe
# Out:
# <bound method DataFrame.describe of <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16977 entries, 2010-11-12 00:00:00 to 2013-11-12 00:00:00
# Data columns (total 61 columns):
# Date              16977  non-null values
# School1           16977  non-null values
# School1_Pace      16977  non-null values
# School1_eFG%      16977  non-null values
# School1_TOV%      16977  non-null values
# School1_ORB%      16977  non-null values
# School1_FT/FGA    16977  non-null values
# School1_ORTG      16977  non-null values
# School2           16977  non-null values
# School2_Pace      16977  non-null values
# School2_eFG%      16977  non-null values
# School2_TOV%      16977  non-null values
# School2_ORB%      16977  non-null values
# School2_FT/FGA    16977  non-null values
# School2_ORTG      16977  non-null values
# School1_Type      16908  non-null values
# School1_MP        16905  non-null values
# School1_FG        16904  non-null values
# ...

# %% [markdown]
# #### Four Factors:

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2010-11-12 00:00:00 to 2010-11-12 00:00:00
# Data columns (total 15 columns):
# Date              5  non-null values
# School1           5  non-null values
# School1_Pace      5  non-null values
# School1_eFG%      5  non-null values
# School1_TOV%      5  non-null values
# School1_ORB%      5  non-null values
# School1_FT/FGA    5  non-null values
# School1_ORTG      5  non-null values
# School2           5  non-null values
# School2_Pace      5  non-null values
# School2_eFG%      5  non-null values
# School2_TOV%      5  non-null values
# School2_ORB%      5  non-null values
# School2_FT/FGA    5  non-null values
# School2_ORTG      5  non-null values
# dtypes: float64(12), object(3)
